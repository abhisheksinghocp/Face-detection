# %%
import cv2
import numpy as np
import os
import math
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2
print (cv2.__version__)
# Out:
# 3.1.0

# %%
webcam = cv2.VideoCapture(0)
ret, frame = webcam.read()
cv2.waitKey(1000)
ret, frame = webcam.read()
print (ret)
webcam.release()
# Out:
# True

# %%
# Open a new thread to manage the external cv2 interaction
cv2.startWindowThread()

# Create a window holder to show you image in
cv2.namedWindow("PyData Tutorial", cv2.WINDOW_NORMAL)
cv2.imshow("PyData Tutorial", frame)
 
# Press any key to close external window
cv2.waitKey()   
cv2.destroyAllWindows()

# %%
# Create a window holder to show you image in
cv2.namedWindow("PyData Tutorial", cv2.WINDOW_AUTOSIZE)
cv2.imshow("PyData Tutorial", frame)

# Press any key to close external window
cv2.waitKey() 
cv2.destroyAllWindows()

# %%
print (type(frame))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(frame)
plt.show()

# %%
# Pixel color conversion
frame_RGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

plt.imshow(frame_RGB)

# Let's take those ugly ticks off
plt.axis("off") 
plt.show()

# %%
cv2.imwrite('A:\people\/picture_GBR.jpg',frame)
cv2.imwrite('A:\people\/picture_RGB.jpg',frame_RGB)

os.system("nautilus images")
# Out:
# 1

# %%
read_mode = 1

picture_GBR = cv2.imread('A:\people\/picture_GBR.jpg', read_mode)
picture_RGB = cv2.imread('A:\people\/picture_RGB.jpg', read_mode)

# numpy intervention
picture = np.hstack((picture_GBR, picture_RGB))
plt.axis("off")
plt.title("GBR   RGB")
plt.imshow(picture, cmap="Greys_r")
plt.show()

# %%
def plt_show(image, title=""):
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.axis("off") 
    plt.title(title)
    plt.imshow(image, cmap="Greys_r")
    plt.show()
